# %% [markdown]
# # Pandas

# %% [markdown]
# Algunos pruebas con pandas

# %%
# import pandas
import pandas as pd
import numpy as np
import requests
import io

# %%
countries="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

# %%
# get dataframe
df = pd.read_csv(countries)
# print a sample of 5 elements
print(df[:5])
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %%
# get a countries column Country copy wihtout header
subset1 = df.iloc[:,0:1].copy()
print(subset1)
# Out:
#                               Country
# 0                             Algeria
# 1                              Angola
# 2                               Benin
# 3                            Botswana
# 4                             Burkina
# 5                             Burundi
# 6                            Cameroon
# 7                          Cape Verde
# 8            Central African Republic
# 9                                Chad
# 10                            Comoros
# 11                              Congo
# 12      Congo, Democratic Republic of
# 13                           Djibouti
# 14                              Egypt
# 15                  Equatorial Guinea
# 16                            Eritrea
# 17                           Ethiopia
# 18                              Gabon
# 19                             Gambia
# 20                              Ghana
# 21                             Guinea
# 22                      Guinea-Bissau
# 23                        Ivory Coast
# ...

# %%
# this is equivalent to get Country column by
subset2 = df[['Country']]
print(subset)
# Out:
#                               Country
# 0                             Algeria
# 1                              Angola
# 2                               Benin
# 3                            Botswana
# 4                             Burkina
# 5                             Burundi
# 6                            Cameroon
# 7                          Cape Verde
# 8            Central African Republic
# 9                                Chad
# 10                            Comoros
# 11                              Congo
# 12      Congo, Democratic Republic of
# 13                           Djibouti
# 14                              Egypt
# 15                  Equatorial Guinea
# 16                            Eritrea
# 17                           Ethiopia
# 18                              Gabon
# 19                             Gambia
# 20                              Ghana
# 21                             Guinea
# 22                      Guinea-Bissau
# 23                        Ivory Coast
# ...

# %%
# add a random population value as new column
df['population'] = pd.Series(np.random.random_integers(1, 1500, len(df)), index=df.index)
print(data)
# Out:
#                               Country         Region  population  \
# 0                             Algeria         AFRICA         101
# 1                              Angola         AFRICA         232
# 2                               Benin         AFRICA         707
# 3                            Botswana         AFRICA         399
# 4                             Burkina         AFRICA         273
# 5                             Burundi         AFRICA        1067
# 6                            Cameroon         AFRICA         753
# 7                          Cape Verde         AFRICA         869
# 8            Central African Republic         AFRICA         540
# 9                                Chad         AFRICA         384
# 10                            Comoros         AFRICA         769
# 11                              Congo         AFRICA         826
# 12      Congo, Democratic Republic of         AFRICA          26
# ...

# %%
# get only africans countries
africans=df.loc[df['Region'].isin(['AFRICA'])]
print(len(africans), africans)
# Out:
# 54                           Country  Region
# 0                         Algeria  AFRICA
# 1                          Angola  AFRICA
# 2                           Benin  AFRICA
# 3                        Botswana  AFRICA
# 4                         Burkina  AFRICA
# 5                         Burundi  AFRICA
# 6                        Cameroon  AFRICA
# 7                      Cape Verde  AFRICA
# 8        Central African Republic  AFRICA
# 9                            Chad  AFRICA
# 10                        Comoros  AFRICA
# 11                          Congo  AFRICA
# 12  Congo, Democratic Republic of  AFRICA
# 13                       Djibouti  AFRICA
# 14                          Egypt  AFRICA
# 15              Equatorial Guinea  AFRICA
# 16                        Eritrea  AFRICA
# 17                       Ethiopia  AFRICA
# 18                          Gabon  AFRICA
# 19                         Gambia  AFRICA
# 20                          Ghana  AFRICA
# ...
